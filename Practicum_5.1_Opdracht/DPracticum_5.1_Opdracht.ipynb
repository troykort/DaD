# %%
import pandas as pd 
import pyodbc
import warnings
warnings.simplefilter('ignore')
import sqlite3
# Out:
# C:\Users\diego\AppData\Local\Temp\ipykernel_23584\169482827.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
DB = {'servername': 'LAPTOPTK\SQLEXPRESS',
'database': 'DAD'}

export_conn = pyodbc.connect('DRIVER={SQL Server}; SERVER=' + DB['servername'] +
                             ';DATABASE=' + DB['database'] + ';Trusted_Connection=yes')
export_cursor = export_conn.cursor()
export_cursor

# %%
DB = {'servername': 'LAPTOP-3S422SS6\\SQLEXPRESS',
'database': 'DAD'}

export_conn = pyodbc.connect('DRIVER={SQL Server}; SERVER=' + DB['servername'] +
                              ';DATABASE=' + DB['database'] + ';Trusted_Connection=yes')
export_cursor = export_conn.cursor()
export_cursor

# %%
Sales_connection= sqlite3.connect("go_sales.sqlite")
Crm_connection= sqlite3.connect("go_crm.sqlite")
inventory_levels = pd.read_csv('GO_SALES_INVENTORY_LEVELSData.csv', index_col=False) 
product_forecast = pd.read_csv('GO_SALES_PRODUCT_FORECASTData.csv', index_col=False)
inventory_levels
# Out:
#       INVENTORY_YEAR  INVENTORY_MONTH  PRODUCT_NUMBER  INVENTORY_COUNT
# 0               2021                4              48             1932
# 1               2021                4              49             1400
# 2               2021                4              50            21705
# 3               2021                4              51             9710
# 4               2021                4              52             5616
# ...              ...              ...             ...              ...
# 3883            2022               12             111             1128
# 3884            2022               12             112             7810
# 3885            2022               12             113             3485
# 3886            2022               12             114              350
# 3887            2022               12             115             3310
#
# [3888 rows x 4 columns]

# %%
newQuery = "SELECT * FROM product"
product = pd.read_sql(newQuery,Sales_connection)
newQuery = "SELECT * FROM product_type"
product_type = pd.read_sql(newQuery,Sales_connection)
newQuery = "SELECT * FROM product_line"
product_line = pd.read_sql(newQuery,Sales_connection)
newQuery = "SELECT * FROM sales_staff"
sales_staff = pd.read_sql(newQuery,Sales_connection)
newQuery = "SELECT * FROM sales_branch"
sales_branch = pd.read_sql(newQuery,Sales_connection)
newQuery = "SELECT * FROM retailer_site"
retailer_site = pd.read_sql(newQuery,Sales_connection)
newQuery = "SELECT * FROM country"
country = pd.read_sql(newQuery,Sales_connection)
newQuery = "SELECT * FROM order_header"
order_header = pd.read_sql(newQuery,Sales_connection)
newQuery = "SELECT * FROM order_details"
order_details = pd.read_sql(newQuery,Sales_connection)
newQuery = "SELECT * FROM SALES_TARGETData"
target = pd.read_sql(newQuery,Sales_connection)
newQuery = "SELECT * FROM returned_item"
returned_item = pd.read_sql(newQuery,Sales_connection)
newQuery = "SELECT * FROM return_reason"
return_reason = pd.read_sql(newQuery,Sales_connection)

newQuery = "SELECT * FROM country"
country_crm = pd.read_sql(newQuery,Crm_connection)
newQuery = "SELECT * FROM retailer_type"
retailer_type = pd.read_sql(newQuery,Crm_connection)
newQuery = "SELECT * FROM retailer_segment"
retailer_segment = pd.read_sql(newQuery,Crm_connection)
newQuery = "SELECT * FROM retailer"
retailer = pd.read_sql(newQuery,Crm_connection)
newQuery = "SELECT * FROM sales_territory"
sales_territory = pd.read_sql(newQuery,Crm_connection)
newQuery = "SELECT * FROM retailer_headquarters"
retailer_headquarters = pd.read_sql(newQuery,Crm_connection)

# %%
Sales_staff_connection=sqlite3.connect('go_staff.sqlite')
Sales_staff_connection

# %%
newQuery= "SELECT * FROM course"
course= pd.read_sql(newQuery,Sales_staff_connection)
newQuery= "SELECT * FROM sales_branch"
sales_branch=pd.read_sql(newQuery,Sales_staff_connection)
newQuery= "SELECT * FROM sales_staff"
sales_staff=pd.read_sql(newQuery,Sales_staff_connection)
newQuery= "SELECT * FROM satisfaction"
satisfaction=pd.read_sql(newQuery,Sales_staff_connection)
newQuery= "SELECT * FROM satisfaction_type"
satisfaction_type=pd.read_sql(newQuery,Sales_staff_connection)
newQuery= "SELECT * FROM training" 
training=pd.read_sql(newQuery,Sales_staff_connection)

# %%
retailer_site_merge = pd.merge(retailer_site, country_crm, on='COUNTRY_CODE', how='left', suffixes=('', '_country'))
retailer_site_merge = pd.merge(retailer_site_merge, sales_territory, on='SALES_TERRITORY_CODE', how='left', suffixes=('', '_sales_territory'))
retailer_site_merge = pd.merge(retailer_site_merge, retailer, on='RETAILER_CODE', how='left', suffixes=('', '_retailer'))
retailer_site_merge = pd.merge(retailer_site_merge, retailer_type, on='RETAILER_TYPE_CODE', how='left', suffixes=('', '_retailer_type'))
retailer_site_merge = pd.merge(retailer_site_merge, retailer_headquarters, on='RETAILER_CODEMR', how='left', suffixes=('', '_retailer_headquarters'))
retailer_site_merge = pd.merge(retailer_site_merge, retailer_segment, on='SEGMENT_CODE', how='left', suffixes=('', '_retailer_segment'))

retailer_site_dimensie = retailer_site_merge[[
    'RETAILER_SITE_CODE', 'ADDRESS1', 'ADDRESS2', 'ACTIVE_INDICATOR', 'COMPANY_NAME', 
    'RETAILER_TYPE_EN', 'SEGMENT_NAME', 'CITY', 'REGION', 'COUNTRY_EN', 'TERRITORY_NAME_EN'
]].copy()

retailer_site_dimensie['ACTIVE_INDICATOR'] = pd.to_numeric(retailer_site_dimensie['ACTIVE_INDICATOR']).astype(int)

retailer_site_dimensie
# Out:
#     RETAILER_SITE_CODE                          ADDRESS1 ADDRESS2  \
# 0                    1                1117 Franklin Blvd     None
# 1                   10  Suite 1500, 802 Docklands Street     None
# 2                  100                    4830 Princeton   Unit 2
# 3                  101                  6630 Burnet Road     None
# 4                  102              2189 Louisville Road     None
# ..                 ...                               ...      ...
# 386                 95                  932 Ohmey Avenue     None
# 387                 96                   438 Kelson Road     None
# 388                 97                3410 Selson Avenue     None
# 389                 98                 73 Stanley Avenue     None
# 390                 99                 37 Raleigh Avenue     None
#
#      ACTIVE_INDICATOR           COMPANY_NAME  RETAILER_TYPE_EN  \
# 0                   1            Rock Steady     Outdoors Shop
# 1                   1  VIP Department Stores  Department Store
# 2                   1      Falcon Outfitters     Outdoors Shop
# 3                   1      Falcon Outfitters     Outdoors Shop
# 4                   0          Trail Masters     Outdoors Shop
# ..                ...                    ...               ...
# 386                 1       Donovan's Sports      Sports Store
# 387                 1       Donovan's Sports      Sports Store
# 388                 1       Donovan's Sports      Sports Store
# 389                 1       Donovan's Sports      Sports Store
# 390                 1       Donovan's Sports      Sports Store
#
#                      SEGMENT_NAME           CITY            REGION  \
# 0                   Outdoors Shop       Winnipeg          Manitoba
# 1    Department Store - Exclusive      Vancouver  British Columbia
# 2       Outdoors Shop - Exclusive    Albuquerque        New Mexico
# 3       Outdoors Shop - Exclusive         Austin             Texas
# 4                   Outdoors Shop   Independence          Kentucky
# ..                            ...            ...               ...
# 386                  Sports Store    Los Angeles        California
# 387                  Sports Store    Los Angeles        California
# 388                  Sports Store      San Diego        California
# 389                  Sports Store  San Francisco        California
# 390                  Sports Store  San Francisco        California
#
#         COUNTRY_EN TERRITORY_NAME_EN
# 0           Canada          Americas
# 1           Canada          Americas
# 2    United States          Americas
# 3    United States          Americas
# 4    United States          Americas
# ..             ...               ...
# 386  United States          Americas
# 387  United States          Americas
# 388  United States          Americas
# 389  United States          Americas
# 390  United States          Americas
#
# [391 rows x 11 columns]

# %%
product_merge = product.merge(product_type, left_on='PRODUCT_TYPE_CODE', right_on='PRODUCT_TYPE_CODE', how='left')
product_merge = product_merge.merge(product_line, left_on='PRODUCT_LINE_CODE', right_on='PRODUCT_LINE_CODE', how='left')
product_dimensie = product_merge[['PRODUCT_NUMBER', 'PRODUCT_TYPE_CODE', 'PRODUCT_NAME', 'DESCRIPTION', 'PRODUCT_TYPE_EN', 'PRODUCT_LINE_EN', 'INTRODUCTION_DATE', 'PRODUCTION_COST', 'MARGIN']]

product_dimensie['INTRODUCTION_DATE'] = pd.to_datetime(product_dimensie['INTRODUCTION_DATE']).dt.date
product_dimensie['PRODUCTION_COST'] = pd.to_numeric(product_dimensie['PRODUCTION_COST']).astype('float').round(2)
product_dimensie['MARGIN'] = pd.to_numeric(product_dimensie['MARGIN']).astype('float').round(2)

product_dimensie
# Out:
#     PRODUCT_NUMBER PRODUCT_TYPE_CODE              PRODUCT_NAME  \
# 0                1                 1       TrailChef Water Bag
# 1               10                 1        TrailChef Utensils
# 2              100                17        Insect Bite Relief
# 3              101                18     Hailstorm Steel Irons
# 4              102                18  Hailstorm Titanium Irons
# ..             ...               ...                       ...
# 110             95                16                Sun Shield
# 111             96                17        Compact Relief Kit
# 112             97                17  Deluxe Family Relief Kit
# 113             98                17           Calamine Relief
# 114             99                17               Aloe Relief
#
#                                            DESCRIPTION PRODUCT_TYPE_EN  \
# 0    Lightweight, collapsible bag to carry liquids ...    Cooking Gear
# 1    Spoon, fork and knife set made of a light yet ...    Cooking Gear
# 2    The Insect Bite Relief helps the itching and s...       First Aid
# 3    Iron is 17-4 stainless steel.  Shafts are grap...           Irons
# 4    Made entirely of pure titanium. The ultimate i...           Irons
# ..                                                 ...             ...
# 110  PABA free sunscreen, SPF 30, poison oak and iv...       Sunscreen
# 111  A personal first aid kit is recommended for ev...       First Aid
# 112  A complete medical kit suitable for families w...       First Aid
# 113  Use the Calamine Relief for allergic skin reac...       First Aid
# 114  Perfect for minor burns and sunburn, the aloe ...       First Aid
#
#         PRODUCT_LINE_EN INTRODUCTION_DATE  PRODUCTION_COST  MARGIN
# 0     Camping Equipment        2011-02-15             4.00    0.33
# 1     Camping Equipment        2011-02-15            10.00    0.40
# 2    Outdoor Protection        2011-02-15             3.00    0.50
# 3        Golf Equipment        2019-12-15           305.54    0.43
# 4        Golf Equipment        2019-12-10           380.95    0.51
# ..                  ...               ...              ...     ...
# 110  Outdoor Protection        2011-02-15             3.00    0.50
# 111  Outdoor Protection        2011-02-15            16.43    0.28
# 112  Outdoor Protection        2013-03-05            25.00    0.28
# 113  Outdoor Protection        2011-02-15             3.00    0.50
# 114  Outdoor Protection        2011-02-15             2.00    0.60
#
# [115 rows x 9 columns]

# %%
date_dimensie = order_header['ORDER_DATE'].drop_duplicates()

product_forecast = product_forecast.rename(columns={'INTRODUCTION_DATE': 'date'})
product_forecast['date'] = pd.to_datetime(product_forecast['YEAR'].astype(str) + '-' + product_forecast['MONTH'].astype(str) + '-01').dt.date
product_forecast_date = product_forecast['date'] 

satisfaction = satisfaction.rename(columns={'YEAR': 'date'})
satisfaction['date'] = pd.to_datetime(satisfaction['date'].astype(str) + '-01-01').dt.date
satisfaction_date = satisfaction['date'].drop_duplicates()

inventory_levels = inventory_levels.rename(columns={'INVENTORY_YEAR': 'date'})
inventory_levels['date'] = pd.to_datetime( inventory_levels['date'].astype(str)+'-'+inventory_levels['INVENTORY_MONTH'].astype(str)+'-01').dt.date
inventory_levels_date =  inventory_levels['date'].drop_duplicates()

# %%
returned_item['RETURN_DATE'] = pd.to_datetime(returned_item['RETURN_DATE'], format='%d-%m-%Y %H:%M:%S')
returned_item_date = returned_item['RETURN_DATE'].dt.date
returned_item_date
# Out:
# 0      2021-08-01
# 1      2020-12-06
# 2      2021-06-24
# 3      2021-07-21
# 4      2020-10-07
#           ...
# 701    2021-06-06
# 702    2021-10-06
# 703    2022-03-31
# 704    2022-12-23
# 705    2020-09-25
# Name: RETURN_DATE, Length: 706, dtype: object

# %%
date_dimensie = pd.to_datetime(date_dimensie).dt.date
product_forecast_date = pd.to_datetime(product_forecast_date).dt.date
satisfaction_date = pd.to_datetime(satisfaction_date).dt.date
inventory_levels_date = pd.to_datetime(inventory_levels_date).dt.date
returned_item_date = pd.to_datetime(returned_item_date).dt.date

all_dates = pd.concat([
    date_dimensie,
    product_forecast_date,
    satisfaction_date,
    inventory_levels_date,
    returned_item_date
])

all_dates_unique = all_dates.drop_duplicates().sort_values()

all_dates_df = all_dates_unique.to_frame(name='date')

all_dates_df['date'] = pd.to_datetime(all_dates_df['date'])

all_dates_df['month'] = all_dates_df['date'].dt.month
all_dates_df['quarter'] = all_dates_df['date'].dt.quarter
all_dates_df['year'] = all_dates_df['date'].dt.year

all_dates_df
# Out:
#           date  month  quarter  year
# 0   2004-01-01      1        1  2004
# 101 2005-01-01      1        1  2005
# 202 2006-01-01      1        1  2006
# 433 2020-01-01      1        1  2020
# 562 2020-01-02      1        1  2020
# ..         ...    ...      ...   ...
# 224 2023-01-12      1        1  2023
# 46  2023-01-25      1        1  2023
# 328 2023-01-26      1        1  2023
# 98  2023-02-02      2        1  2023
# 73  2023-02-04      2        1  2023
#
# [1014 rows x 4 columns]

# %%
order = pd.merge(order_details,order_header,left_on='ORDER_NUMBER',how='left',right_on='ORDER_NUMBER')
order_fact = order[['ORDER_NUMBER','ORDER_DETAIL_CODE','QUANTITY','UNIT_COST','UNIT_PRICE','UNIT_SALE_PRICE','PRODUCT_NUMBER','RETAILER_SITE_CODE','SALES_STAFF_CODE','ORDER_DATE']]
order_fact
# Out:
#       ORDER_NUMBER ORDER_DETAIL_CODE  QUANTITY UNIT_COST UNIT_PRICE  \
# 0             8462            100000        16      16.1      22.54
# 1             9111            100001        20      16.1      22.54
# 2             8451            100002        24      16.1      22.54
# 3             8453            100003        18      16.1      22.54
# 4             8439            100004        20      16.1      22.54
# ...            ...               ...       ...       ...        ...
# 43058         8459             99995       146      2.76       5.55
# 43059         8457             99996       172      2.76       5.55
# 43060         9267             99997       192      2.76       5.55
# 43061         8441             99998       192      2.76       5.55
# 43062         8440             99999        22      16.1      22.54
#
#       UNIT_SALE_PRICE PRODUCT_NUMBER RETAILER_SITE_CODE SALES_STAFF_CODE  \
# 0               22.54             96                334               95
# 1               22.54             96                330               94
# 2               22.54             96                328               94
# 3               22.54             96                328               94
# 4               22.54             96                326               95
# ...               ...            ...                ...              ...
# 43058            5.55             95                333               95
# 43059            5.55             95                333               95
# 43060            5.55             95                334               95
# 43061            5.55             95                326               95
# 43062           22.54             96                326               95
#
#        ORDER_DATE
# 0      2020-07-26
# 1      2020-05-29
# 2      2020-04-17
# 3      2020-08-19
# 4      2020-03-19
# ...           ...
# 43058  2020-08-20
# 43059  2020-04-04
# 43060  2020-11-20
# 43061  2020-07-30
# 43062  2020-09-27
#
# [43063 rows x 10 columns]

# %%
date_export_cursor = export_conn.cursor()

for index, row in all_dates_df.iterrows():
    try:
        query = f"""
        INSERT INTO DATE 
        (DATE_date, DATE_MONTH_nr, DATE_QUARTER_nr, DATE_YEAR_nr) 
        VALUES 
        ('{row['date']}', {row['month']}, {row['quarter']}, {row['year']});
        """
        date_export_cursor.execute(query)
    except pyodbc.Error as e:
        print("An error occurred:", e)
        print(query)

export_conn.commit()
date_export_cursor.close()

# %%
export_cursor = export_conn.cursor()  

for index, row in product_dimensie.iterrows():
    try:
        query = f"""
        INSERT INTO PRODUCT 
        (PRODUCT_id, PRODUCT_name, PRODUCT_description, PRODUCT_TYPE_name, PRODUCT_LINE_name, 
        PRODUCT_INTRODUCTION_DATE_date, PRODUCT_COST_nr, PRODUCT_MARGIN_nr) 
        VALUES 
        ({row['PRODUCT_NUMBER']}, '{row['PRODUCT_NAME'].replace("'", "''")}', 
        '{row['DESCRIPTION'].replace("'", "''")}', '{row['PRODUCT_TYPE_EN'].replace("'", "''")}', 
        '{row['PRODUCT_LINE_EN'].replace("'", "''")}', '{row['INTRODUCTION_DATE']}', 
        {row['PRODUCTION_COST']}, {row['MARGIN']});
        """
        export_cursor.execute(query)
    except pyodbc.Error as e:
        print("An error occurred:", e)
        print(query)

export_conn.commit()  
export_cursor.close()

# %%
export_cursor = export_conn.cursor()  

for index, row in retailer_site_dimensie.iterrows():
    try:
        retailer_site_id = row['RETAILER_SITE_CODE']
        address1 = f"'{row['ADDRESS1'].replace("'", "''")}'" if pd.notna(row['ADDRESS1']) else 'NULL'
        address2 = f"'{row['ADDRESS2'].replace("'", "''")}'" if pd.notna(row['ADDRESS2']) else 'NULL'
        active_indicator = row['ACTIVE_INDICATOR']
        company_name = f"'{row['COMPANY_NAME'].replace("'", "''")}'" if pd.notna(row['COMPANY_NAME']) else 'NULL'
        retailer_type_en = f"'{row['RETAILER_TYPE_EN'].replace("'", "''")}'" if pd.notna(row['RETAILER_TYPE_EN']) else 'NULL'
        segment_name = f"'{row['SEGMENT_NAME'].replace("'", "''")}'" if pd.notna(row['SEGMENT_NAME']) else 'NULL'
        city = f"'{row['CITY'].replace("'", "''")}'" if pd.notna(row['CITY']) else 'NULL'
        region = f"'{row['REGION'].replace("'", "''")}'" if pd.notna(row['REGION']) else 'NULL'
        country_en = f"'{row['COUNTRY_EN'].replace("'", "''")}'" if pd.notna(row['COUNTRY_EN']) else 'NULL'
        territory_name_en = f"'{row['TERRITORY_NAME_EN'].replace("'", "''")}'" if pd.notna(row['TERRITORY_NAME_EN']) else 'NULL'

        query = f"""
        INSERT INTO RETALER_SITE (
            RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2, 
            RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name, 
            RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name, 
            RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname, 
            RETALER_SITE_TERRITORY_name
        ) VALUES (
            {retailer_site_id}, {address1}, {address2}, 
            {active_indicator}, {company_name}, {retailer_type_en}, 
            {segment_name}, {city}, {region}, {country_en}, {territory_name_en}
        );
        """
        export_cursor.execute(query)
    except pyodbc.Error as e:
        print("An error occurred:", e)
        print(query)
        
export_conn.commit()
export_cursor.close()
# Out:
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (1). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             1, '1117 Franklin Blvd', NULL,
#             1, 'Rock Steady', 'Outdoors Shop',
#             'Outdoors Shop', 'Winnipeg', 'Manitoba', 'Canada', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (10). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             10, 'Suite 1500, 802 Docklands Street', NULL,
#             1, 'VIP Department Stores', 'Department Store',
#             'Department Store - Exclusive', 'Vancouver', 'British Columbia', 'Canada', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (100). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             100, '4830 Princeton', 'Unit 2',
#             1, 'Falcon Outfitters', 'Outdoors Shop',
#             'Outdoors Shop - Exclusive', 'Albuquerque', 'New Mexico', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (101). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             101, '6630 Burnet Road', NULL,
#             1, 'Falcon Outfitters', 'Outdoors Shop',
#             'Outdoors Shop - Exclusive', 'Austin', 'Texas', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (102). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             102, '2189 Louisville Road', NULL,
#             0, 'Trail Masters', 'Outdoors Shop',
#             'Outdoors Shop', 'Independence', 'Kentucky', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (103). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             103, '1700 George Street', 'Suite 1B',
#             1, 'Second Wind Sports', 'Sports Store',
#             'Sports Store', 'San Francisco', 'California', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (104). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             104, '121 Dove Street', NULL,
#             1, 'Second Wind Sports', 'Sports Store',
#             'Sports Store', 'Albany', 'New York', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (105). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             105, '36 Burside Street', NULL,
#             1, 'Second Wind Sports', 'Sports Store',
#             'Sports Store', 'New York', 'New York', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (106). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             106, '3728 Lester Avenue', NULL,
#             1, 'Second Wind Sports', 'Sports Store',
#             'Sports Store', 'New York', 'New York', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (107). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             107, '283 Mondela Street', NULL,
#             1, 'Second Wind Sports', 'Sports Store',
#             'Sports Store', 'Dallas', 'Texas', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (108). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             108, '2893 South 700 West', NULL,
#             1, 'Second Wind Sports', 'Sports Store',
#             'Sports Store', 'Salt Lake City', 'Utah', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (109). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             109, '266 S. Christopher Road', NULL,
#             1, 'The Golf Hut', 'Golf Shop',
#             'Golf Shop', 'Chapel Hill', 'North Carolina', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (11). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             11, 'Suite 125, 129th Street', NULL,
#             1, 'VIP Department Stores', 'Department Store',
#             'Department Store - Exclusive', 'Vancouver', 'British Columbia', 'Canada', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (110). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             110, '1488 Orleans Road', 'P.O. Box 1128',
#             1, 'The Golf Hut', 'Golf Shop',
#             'Golf Shop', 'Charleston', 'South Carolina', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (111). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             111, '172 N. Cave Creek Road', NULL,
#             1, 'Buena Vista Eyeware', 'Eyewear Store',
#             'Eyewear Store', 'Phoenix', 'Arizona', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (112). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             112, '518 Colombe Street', NULL,
#             1, 'Buena Vista Eyeware', 'Eyewear Store',
#             'Eyewear Store', 'San Francisco', 'California', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (113). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             113, '19 Cavicta Avenue', NULL,
#             1, 'Jack and Jill Climbing School & Supplies', 'Outdoors Shop',
#             NULL, 'Boulder', 'Colorado', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (114). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             114, '3278 Crest Avenue', NULL,
#             1, 'Edward''s Department Store', 'Department Store',
#             'Department Store', 'Houston', 'Texas', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (115). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             115, '272 Main Street', NULL,
#             1, 'Edward''s Department Store', 'Department Store',
#             'Department Store', 'Montpelier', 'Vermont', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (116). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             116, '938 Jasmine Crescent', NULL,
#             1, 'Edward''s Department Store', 'Department Store',
#             'Department Store', 'Richmond', 'Virginia', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (117). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             117, '325 Wayside Street', NULL,
#             1, 'Edward''s Department Store', 'Department Store',
#             'Department Store', 'Seattle', 'Washington', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (118). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             118, '433 West Broadway', NULL,
#             1, 'Edward''s Department Store', 'Department Store',
#             'Department Store', 'Madison', 'Wisconsin', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (119). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             119, '4881 East Second Street', NULL,
#             1, 'Edward''s Department Store', 'Department Store',
#             'Department Store', 'Casper', 'Wyoming', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (12). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             12, 'Suite 5034, 34 Broadway Street', NULL,
#             1, 'VIP Department Stores', 'Department Store',
#             'Department Store - Exclusive', 'Vancouver', 'British Columbia', 'Canada', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (120). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             120, '2015 Charles Drive', NULL,
#             0, 'Parkland Camping Rentals', 'Equipment Rental Store',
#             NULL, 'Dover', 'Delaware', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (121). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             121, '16823 Atlantic Blvd.', NULL,
#             1, 'Parkland Camping Rentals', 'Equipment Rental Store',
#             NULL, 'Jacksonville', 'Florida', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (122). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             122, '235 Salter Street', NULL,
#             1, 'Parkland Camping Rentals', 'Equipment Rental Store',
#             NULL, 'Miami', 'Florida', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (123). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             123, '6392 Lakewood Avenue', NULL,
#             1, 'Parkland Camping Rentals', 'Equipment Rental Store',
#             NULL, 'Atlanta', 'Georgia', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (124). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             124, '2103 Ashbury Street', 'P.O. Box 2167',
#             1, 'Consumer Club', 'Warehouse Store',
#             'Warehouse Store', 'Los Angeles', 'California', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (125). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             125, '333 Ustaff Way', 'Suite 67',
#             1, 'Consumer Club', 'Warehouse Store',
#             'Warehouse Store', 'San Diego', 'California', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (126). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             126, '76 Young Avenue', NULL,
#             1, 'Consumer Club', 'Warehouse Store',
#             'Warehouse Store', 'Denver', 'Colorado', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (127). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             127, '3411 Champlain Street, NW', 'Suite 110',
#             1, 'Consumer Club', 'Warehouse Store',
#             'Warehouse Store', 'Washington', 'DC', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (128). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             128, '1378 Toley Acres Road', NULL,
#             1, 'Consumer Club', 'Warehouse Store',
#             'Warehouse Store', 'Miami', 'Florida', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (129). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             129, '2384 Klein Street', NULL,
#             1, 'Consumer Club', 'Warehouse Store',
#             'Warehouse Store', 'Atlanta', 'Georgia', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (13). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             13, '18, rue Rousseau', NULL,
#             1, 'VIP Department Stores', 'Department Store',
#             'Department Store - Exclusive', 'Montréal', 'Québec', 'Canada', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (130). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             130, '35 Independence Drive', NULL,
#             1, 'Connor Department Store', 'Department Store',
#             'Department Store', 'Birmingham', 'Alabama', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (131). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             131, '937 Hilson Crescent', 'Suite 2-4',
#             1, 'Connor Department Store', 'Department Store',
#             'Department Store', 'Boston', 'Massachusetts', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (132). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             132, '992 Delton Crescent', NULL,
#             1, 'Connor Department Store', 'Department Store',
#             'Department Store', 'Boston', 'Massachusetts', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (133). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             133, '5890 McCoy Drive', NULL,
#             1, 'Connor Department Store', 'Department Store',
#             'Department Store', 'Jackson', 'Mississippi', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (134). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             134, '809 Main Street', NULL,
#             1, 'Connor Department Store', 'Department Store',
#             'Department Store', 'Lake Placid', 'New York', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (135). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             135, '231 Linson Street', NULL,
#             1, 'By A Thread', 'Outdoors Shop',
#             'Outdoors Shop', 'Boulder', 'Colorado', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (136). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             136, '832 Rourson Avenue', NULL,
#             1, 'By A Thread', 'Outdoors Shop',
#             'Outdoors Shop', 'Denver', 'Colorado', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (137). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             137, '357 Trent Road', NULL,
#             1, 'By A Thread', 'Outdoors Shop',
#             'Outdoors Shop', 'Salt Lake City', 'Utah', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (138). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             138, '832 Mill Avenue', 'Unit 17',
#             1, 'Hartman''s', 'Department Store',
#             'Department Store', 'Phoenix', 'Arizona', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (139). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             139, '7773 Green Park Road', NULL,
#             1, 'Hartman''s', 'Department Store',
#             'Department Store', 'Tucson', 'Arizona', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (14). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             14, '500, Place d''Armes', 'Bureau 1061',
#             1, 'Le Golfeur', 'Golf Shop',
#             'Golf Shop', 'Montréal', 'Québec', 'Canada', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (140). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             140, '3866 Point Circle', NULL,
#             1, 'Hartman''s', 'Department Store',
#             'Department Store', 'Little Rock', 'Arkansas', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (141). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             141, '1201 N. State College Blvd.', NULL,
#             0, 'Hartman''s', 'Department Store',
#             'Department Store', 'Anaheim', 'California', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (142). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
# ...
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             84, '7543 South Carson Street', NULL,
#             1, 'Extreme Outdoors', 'Outdoors Shop',
#             'Outdoors Shop', 'Carson City', 'Nevada', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (85). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             85, '738 Stoney Road', NULL,
#             1, 'Extreme Outdoors', 'Outdoors Shop',
#             'Outdoors Shop', 'Las Vegas', 'Nevada', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (86). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             86, '702 North Meridian', 'Suite 220',
#             1, 'Extreme Outdoors', 'Outdoors Shop',
#             'Outdoors Shop', 'Oklahoma City', 'Oklahoma', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (87). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             87, '1210 Somerville Avenue', 'P.O. Box 4390',
#             1, 'Extreme Outdoors', 'Outdoors Shop',
#             'Outdoors Shop', 'Chattanooga', 'Tennessee', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (88). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             88, '83 Nirson Road', NULL,
#             1, 'Extreme Outdoors', 'Outdoors Shop',
#             'Outdoors Shop', 'Houston', 'Texas', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (89). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             89, '628 Prince Street', NULL,
#             1, 'Extreme Outdoors', 'Outdoors Shop',
#             'Outdoors Shop', 'Alexandria', 'Virginia', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (9). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             9, '601 Bay Street', NULL,
#             1, 'VIP Department Stores', 'Department Store',
#             'Department Store - Exclusive', 'Toronto', 'Ontario', 'Canada', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (90). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             90, '17432 Aurora Ave. N.', NULL,
#             1, 'Extreme Outdoors', 'Outdoors Shop',
#             'Outdoors Shop', 'Seattle', 'Washington', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (91). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             91, '1733 Christopher Street', NULL,
#             1, 'Extreme Outdoors', 'Outdoors Shop',
#             'Outdoors Shop', 'Charleston', 'West Virginia', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (92). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             92, '1809 Tusalane Avenue', NULL,
#             0, 'Eye Dimensions', 'Eyewear Store',
#             'Eyewear Store', 'Miami', 'Florida', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (93). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             93, '804 Fawcett Road', NULL,
#             1, 'Eye Dimensions', 'Eyewear Store',
#             'Eyewear Store', 'Atlanta', 'Georgia', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (94). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             94, '832 Vensa Crescent', NULL,
#             1, 'Eye Dimensions', 'Eyewear Store',
#             'Eyewear Store', 'Dallas', 'Texas', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (95). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             95, '932 Ohmey Avenue', NULL,
#             1, 'Donovan''s Sports', 'Sports Store',
#             'Sports Store', 'Los Angeles', 'California', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (96). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             96, '438 Kelson Road', NULL,
#             1, 'Donovan''s Sports', 'Sports Store',
#             'Sports Store', 'Los Angeles', 'California', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (97). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             97, '3410 Selson Avenue', NULL,
#             1, 'Donovan''s Sports', 'Sports Store',
#             'Sports Store', 'San Diego', 'California', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (98). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             98, '73 Stanley Avenue', NULL,
#             1, 'Donovan''s Sports', 'Sports Store',
#             'Sports Store', 'San Francisco', 'California', 'United States', 'Americas'
#         );
#
# An error occurred: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__RETALER___F6FE6073A8DFD825'. Cannot insert duplicate key in object 'dbo.RETALER_SITE'. The duplicate key value is (99). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
#         INSERT INTO RETALER_SITE (
#             RETALER_SITE_id, RETALER_SITE_adress1, RETALER_SITE_adress2,
#             RETALER_SITE_ACTIVE_INDICATOR_nr, RETALER_SITE_RETAILER_name,
#             RETALER_SITE_RETAILER_TYPE_name, RETALER_SITE_SEGMENT_name,
#             RETALER_SITE_CITY_name, RETALER_SITE_REGION_name, RETALER_SITE_COUNTRYname,
#             RETALER_SITE_TERRITORY_name
#         ) VALUES (
#             99, '37 Raleigh Avenue', NULL,
#             1, 'Donovan''s Sports', 'Sports Store',
#             'Sports Store', 'San Francisco', 'California', 'United States', 'Americas'
#         );

# %%
merged_sales_staff = pd.merge(sales_staff, sales_staff, left_on='MANAGER_CODE', right_on='SALES_STAFF_CODE', suffixes=('_staff', '_manager'))

selected_columns = [
    'SALES_STAFF_CODE_staff',
    'FIRST_NAME_staff',
    'LAST_NAME_staff',
    'EXTENSION_staff',
    'EMAIL_staff',
    'WORK_PHONE_staff',
    'MANAGER_CODE_staff',
    'DATE_HIRED_staff',
    'SALES_BRANCH_CODE_staff',
    'FIRST_NAME_manager',
    'LAST_NAME_manager'
]

sales_staff_DIMENSION = merged_sales_staff[selected_columns].rename(columns={
    'FIRST_NAME_staff': 'FIRST_NAME',
    'LAST_NAME_staff': 'LAST_NAME',
    'FIRST_NAME_manager': 'MANAGER_FIRST_NAME',
    'LAST_NAME_manager': 'MANAGER_LAST_NAME'
})
sales_staff_DIMENSION['MANAGER_NAME'] = sales_staff_DIMENSION['MANAGER_FIRST_NAME'] + ' ' + sales_staff_DIMENSION['MANAGER_LAST_NAME']
sales_staff_DIMENSION.drop(columns=['MANAGER_FIRST_NAME', 'MANAGER_LAST_NAME'], inplace=True)

sales_staff_DIMENSION
# Out:
#     SALES_STAFF_CODE_staff FIRST_NAME   LAST_NAME EXTENSION_staff  \
# 0                      100     Tuomas  Savolainen             825
# 1                      101   Chang-ho         Kim            1228
# 2                      102    Jung-ho        Choi            2641
# 3                      103  Kwei-Ping         Kao            1541
# 4                      104  Chin-Tsai        Fang            2311
# ..                     ...        ...         ...             ...
# 97                      95      Tomás    Iglesias             325
# 98                      96     Bayard       Lopes            3490
# 99                      97     Viviam      Barros            3364
# 100                     98    Eduardo   Guimarães            1442
# 101                     99     Helena    Lindholm             489
#
#                  EMAIL_staff     WORK_PHONE_staff MANAGER_CODE_staff  \
# 0    TSavolainen@grtd123.com  +358(0)17 - 433 127                 18
# 1           CKim@grtd123.com        82-2-778-6587                 87
# 2          JChoi@grtd123.com        82-2-778-6587                 87
# 3          KKwao@grtd123.com      886-2-2975-1988                 87
# 4           CFon@grtd123.com      886-2-2975-1988                 87
# ..                       ...                  ...                ...
# 97     TIglesias@grtd123.com      +35 94 322 3540                 18
# 98        BLopes@grtd123.com    +55 (11) 344-4444                 71
# 99       VBarros@grtd123.com    +55 (11) 344-4444                 96
# 100   EGuimaraes@grtd123.com    +55 (11) 344-4444                 96
# 101    HLindholm@grtd123.com  +358(0)17 - 433 127                 18
#
#             DATE_HIRED_staff SALES_BRANCH_CODE_staff     MANAGER_NAME
# 0    23-Jul-1998 12:00:00 AM                      31       Jörg Kunze
# 1    15-Dec-1998 12:00:00 AM                      32   Kazumi Uragome
# 2    27-Nov-1998 12:00:00 AM                      32   Kazumi Uragome
# 3    07-Oct-1998 12:00:00 AM                      33   Kazumi Uragome
# 4    08-May-1996 12:00:00 AM                      33   Kazumi Uragome
# ..                       ...                     ...              ...
# 97   19-Feb-1998 12:00:00 AM                      29       Jörg Kunze
# 98   12-Aug-1997 12:00:00 AM                      30  Estelle Johnson
# 99   10-Feb-2001 12:00:00 AM                      30     Bayard Lopes
# 100  14-Feb-1999 12:00:00 AM                      30     Bayard Lopes
# 101  17-Aug-1997 12:00:00 AM                      31       Jörg Kunze
#
# [102 rows x 10 columns]
